# %%
# TP 1 : Les bases de Python - Les Boucles et Conditions

### Exercice 1 : Filtrer les nombres pairs
**Consigne :** Écrivez une fonction `filtrer_pairs(liste_nombres)` qui prend en paramètre une liste d'entiers et qui **renvoie une nouvelle liste** contenant uniquement les nombres pairs.

*Exemple attendu :* `filtrer_pairs([1, 2, 3, 4])` doit renvoyer `[2, 4]`.

# %%
def filtrer_pairs(liste_nombres):
    # Écris ton code ici pour tester

# %%
import sys
import os
sys.path.append(os.path.abspath('.'))

from ui.chat_widget import TPChatInterface

consigne = "Créer une fonction filtrer_pairs(liste_nombres) utilisant une boucle for et un if avec modulo % pour isoler les nombres pairs d'une liste."
interface = TPChatInterface(consigne)
interface.render()
